# %%
# Import necessary libraries
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize

# Download required NLTK data files
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\kunal\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\kunal\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# Example text document
text = """
Natural Language Processing (NLP) is a field of Artificial Intelligence
that enables computers to understand, interpret, and generate human language.
It is used in applications like chatbots, sentiment analysis, and machine translation.
"""
print("Original Text:\n", text)
# Out:
# Original Text:
#
# Natural Language Processing (NLP) is a field of Artificial Intelligence
# that enables computers to understand, interpret, and generate human language.
# It is used in applications like chatbots, sentiment analysis, and machine translation.

# %% [markdown]
# ## Tokenization

# %%
# Tokenize the text (split into words)
tokens = word_tokenize(text.lower())  # converting to lowercase
print("Tokens:\n", tokens)
# Out:
# Tokens:
#  ['natural', 'language', 'processing', '(', 'nlp', ')', 'is', 'a', 'field', 'of', 'artificial', 'intelligence', 'that', 'enables', 'computers', 'to', 'understand', ',', 'interpret', ',', 'and', 'generate', 'human', 'language', '.', 'it', 'is', 'used', 'in', 'applications', 'like', 'chatbots', ',', 'sentiment', 'analysis', ',', 'and', 'machine', 'translation', '.']

# %% [markdown]
# ## Stop Word Removal

# %%
# Testing whether nltk_data is installed properly or not

# Get English stopwords
stop_words = set(stopwords.words('english'))

# Remove stopwords
filtered_tokens = [word for word in tokens if word.isalpha() and word not in stop_words]
print("After Stop Word Removal:\n", filtered_tokens)
# Out:
# After Stop Word Removal:
#  ['natural', 'language', 'processing', 'nlp', 'field', 'artificial', 'intelligence', 'enables', 'computers', 'understand', 'interpret', 'generate', 'human', 'language', 'used', 'applications', 'like', 'chatbots', 'sentiment', 'analysis', 'machine', 'translation']

# %% [markdown]
# ## Stemming

# %%
# Initialize the Porter Stemmer
stemmer = PorterStemmer()

# Apply stemming
stemmed_words = [stemmer.stem(word) for word in filtered_tokens]
print("After Stemming:\n", stemmed_words)
# Out:
# After Stemming:
#  ['natur', 'languag', 'process', 'nlp', 'field', 'artifici', 'intellig', 'enabl', 'comput', 'understand', 'interpret', 'gener', 'human', 'languag', 'use', 'applic', 'like', 'chatbot', 'sentiment', 'analysi', 'machin', 'translat']

# %%
# Join the stemmed words back into a single string
processed_text = ' '.join(stemmed_words)
print("Final Preprocessed Text:\n", processed_text)
# Out:
# Final Preprocessed Text:
#  natur languag process nlp field artifici intellig enabl comput understand interpret gener human languag use applic like chatbot sentiment analysi machin translat
